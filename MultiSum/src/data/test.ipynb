# %%
import numpy as np

s = np.load('frames/ANIAMP0000.npy')
x  = np.load('videos_frame/COOPOA0025.npy')

# %%
s.shape
# Out:
# (99, 720, 1280, 3)

# %%
s
# Out:
# array([[[[156, 214, 122],
#          [156, 214, 122],
#          [156, 214, 122],
#          ...,
#          [118, 194,  64],
#          [118, 194,  64],
#          [118, 194,  64]],
#
#         [[156, 214, 122],
#          [156, 214, 122],
#          [156, 214, 122],
#          ...,
#          [118, 194,  64],
#          [118, 194,  64],
#          [118, 194,  64]],
#
#         [[156, 214, 122],
#          [156, 214, 122],
#          [156, 214, 122],
#          ...,
#          [118, 194,  64],
#          [118, 194,  64],
#          [118, 194,  64]],
#
#         ...,
#
#         [[118, 194,  64],
#          [118, 194,  64],
#          [118, 194,  64],
#          ...,
#          [156, 214, 122],
#          [156, 214, 122],
#          [156, 214, 122]],
#
#         [[118, 194,  64],
#          [118, 194,  64],
#          [118, 194,  64],
#          ...,
#          [156, 214, 122],
#          [156, 214, 122],
#          [156, 214, 122]],
#
#         [[118, 194,  64],
# ...

# %%
x.shape
# Out:
# (99, 2048)

# %%
from PIL import Image
num = 10
image = Image.fromarray(s[num])
image.save(f'image{num}.png')

# %%
image = Image.open(f'image{num}.png')
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1280x720>
